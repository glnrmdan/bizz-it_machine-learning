# %%
import base64
import io
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
# request data
im = '/home/irizqy/ml_ws/bangkit-ws/data/temp/jj_6.jpeg'
# im = '/home/irizqy/ml_ws/bangkit-ws/data/bizit-dev_test-data/32.jpg'
# im = '/home/irizqy/Downloads/rfc.jpg'

with open(im, "rb") as f:
    im_bytes = f.read()    
print(im_bytes)    
# im_b64 = base64.b64encode(im_bytes).decode("utf8")
# print(type(im_b64))
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x02\x00\x02\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd
# ...

# %%
jpg_original = base64.b64decode(im_b64.encode('utf-8'))
jpg_as_np = np.frombuffer(jpg_original, dtype=np.uint8)
img = cv.imdecode(jpg_as_np, flags=1)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
from PIL import Image

img_bytes = base64.b64decode(im_b64.encode('utf-8'))
im = Image.open(io.BytesIO(img_bytes)).resize((512, 512))
im_arr = np.asarray(im)

plt.imshow(im_arr)

# %%
import requests
import json
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# import io
# from PIL import Image

req = requests.get('https://bizzit-387412.as.r.appspot.com/franchises')
franchise_item = json.loads(req.content.decode())['data']
demo_data = franchise_item[0]

logo = requests.get(demo_data['logo']).content
jpg_as_np = np.frombuffer(logo, dtype=np.uint8)
im_arr = cv.imdecode(jpg_as_np, flags=1)
im_arr = cv.cvtColor(im_arr, cv.COLOR_BGR2RGB)
plt.imshow(im_arr)

# logo_req = requests.get(logo)
# print(type(logo_req.content))
# img = Image.open(io.BytesIO(logo_req.content))
# img.show()

# %%
import app.functions as f
import matplotlib.pyplot as plt

f.get_franchise_data()
# Out:
# {'id': 'f6c50360-2389-462f-951a-98d3caa870de',
#  'logo': 'https://storage.googleapis.com/bizzit-387412.appspot.com/logo-Company%20Google_1686571110466'}
